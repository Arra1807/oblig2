# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = pd.read_csv("TSLA.csv")
df
df.plot.scatter(x= "Date",y ="Close")
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
df = pd.read_csv("TSLA.csv")
import datetime as dt 
df["Date"] = pd.to_datetime(df["Date"])
df["Date"] = df["Date"].map(dt.datetime.toordinal)
df.head()
# Out:
#      Date        Open        High         Low       Close   Adj Close  \
# 0  738452  205.820007  213.500000  198.589996  211.250000  211.250000
# 1  738453  210.100006  224.350006  210.000000  222.419998  222.419998
# 2  738454  219.399994  230.600006  218.199997  224.639999  224.639999
# 3  738455  229.770004  233.809998  222.850006  225.089996  225.089996
# 4  738456  225.399994  228.860001  216.350006  228.520004  228.520004
#
#       Volume
# 0  100446800
# 1   96507900
# 2   85012500
# 3   61638800
# 4   69152400

# %%
y = pd.DataFrame(df["Close"]) #Output
y
X = pd.DataFrame(df["Date"]) #Input
X
X_train, X_test, y_train,y_test = train_test_split(X, y,test_size = 0.33,random_state = 42)#Splitting into test and train
linear_regression = LinearRegression() #Variable for LinearRegression
linear_regression.fit(X_train,y_train) #Training the model
y_train_pred = linear_regression.predict(X_train) #train prediction 
y_train_pred
y_test_pred = linear_regression.predict(X_test) #test prediction
y_test_pred
lr_train_mse = metrics.mean_squared_error(y_train,y_train_pred) #calculating MSE for training set 
lr_test_mse = metrics.mean_squared_error(y_test,y_test_pred) #calculating MSE for testing set
lr_train_r2score = metrics.r2_score(y_train,y_train_pred)*100 #Measure how well the regression line approximates the actual data
lr_test_r2score = metrics.r2_score(y_test,y_test_pred)*100 #Measure how well the regression line approximates the actual data
print( "MSE = "+str(metrics.mean_squared_error(y_test,y_test_pred)))
print("r2_train="+str(metrics.r2_score(y_train,y_train_pred)*100))
print("r2_test="+str(metrics.r2_score(y_test,y_test_pred)*100))
plt.scatter(X_train, y_train) #plots blue dots with real data
plt.plot(X_train, y_pred, color= "red") #plots red line with prediction
plt.show
#x=pd.DataFrame(df['Date'])
#y=pd.DataFrame(df['Close'])
plt.xlabel("Date")
plt.ylabel("Close")
y_pred = pd.DataFrame(y_train_pred) #
print( "MSE = "+str(metrics.mean_squared_error(y_train,y_train_pred)))
# Out:
# MSE = 896.3148478171208
# r2_train=49.56052749412363
# r2_test=50.424333916944164
# MSE = 1057.8723850688134

# %% [markdown]
# ###
